# %%
# !pip install plotnine
# Out:
# Looking in indexes: https://pypi.org/simple, https://automatic-winner-f2bdec75.pages.github.io
# Requirement already satisfied: plotnine in /home/hewelber/anaconda3/lib/python3.8/site-packages (0.8.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from plotnine) (0.12.2)
# Requirement already satisfied: descartes>=1.1.0 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from plotnine) (1.1.0)
# Requirement already satisfied: mizani>=0.7.3 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from plotnine) (0.7.3)
# Requirement already satisfied: pandas>=1.1.0 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from plotnine) (1.1.4)
# Requirement already satisfied: matplotlib>=3.1.1 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from plotnine) (3.5.2)
# Requirement already satisfied: numpy>=1.19.0 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from plotnine) (1.22.3)
# Requirement already satisfied: patsy>=0.5.1 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from plotnine) (0.5.1)
# Requirement already satisfied: scipy>=1.5.0 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from plotnine) (1.6.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (9.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (20.9)
# Requirement already satisfied: six in /home/hewelber/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=3.1.1->plotnine) (1.15.0)
# Requirement already satisfied: palettable in /home/hewelber/anaconda3/lib/python3.8/site-packages (from mizani>=0.7.3->plotnine) (3.3.0)
# Requirement already satisfied: pytz>=2017.2 in /home/hewelber/anaconda3/lib/python3.8/site-packages (from pandas>=1.1.0->plotnine) (2022.1)

# %%
import sys
sys.path.insert(0,'../src')

# %%
import pandas as pd
import numpy as np
from otto_layout.colors import *
from otto_layout.themes import *
from plotnine import *
# Out:
# ../src/otto_layout/../../fonts
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSansKO-Black-2v2b.otf
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSans-Bold-2v2b.otf
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSans-RegularItalic-2v2b.otf
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSansCondKO-Medium-2v2b.otf
# /home/hewelber/git/herwinvw/otto_layout/fonts/xkcd.ttf
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSans-BoldItalic-2v2b.otf
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSans-Regular-2v2b.otf
# /home/hewelber/git/herwinvw/otto_layout/fonts/comic-sans-ms.ttf
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSansKO-Medium-2v2b.otf
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSansCond-Bold-2v2b.otf
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSansCondKO-Black-2v2b.otf
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSans-Thin-2v2b.otf
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSansCond-Regular-2v2b.otf
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSans-ThinItalic-2v2b.otf
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSans-Light-2v2b.otf
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSansCond-Thin-2v2b.otf
# /home/hewelber/git/herwinvw/otto_layout/fonts/xkcd-script.ttf
# /home/hewelber/git/herwinvw/otto_layout/fonts/OTTOSansKO-BlackItalic-2v2b.otf

# %% [markdown]
# # Plot a sinus wave

# %%
t = np.arange(0,10, step=0.01)
y = np.cos(t)

# %%
df = pd.DataFrame({'t':t, 'y':y})

# %%
ggplot(df, aes(x='t', y='y'))+geom_line(color=otto_rot)+theme_otto()
# Out:
# <ggplot: (8741118476743)>

# %%
sin_t = np.sin(t)
cos_t = np.cos(t)
df = pd.DataFrame({'t':t, 'sin':sin_t, 'cos':cos_t})
df = df.melt(id_vars='t', var_name='function', value_name='y')
df.head()
# Out:
#       t function         y
# 0  0.00      sin  0.000000
# 1  0.01      sin  0.010000
# 2  0.02      sin  0.019999
# 3  0.03      sin  0.029996
# 4  0.04      sin  0.039989

# %%
ggplot(df, aes(x='t', y='y', color='function'))+geom_line()+scale_color_manual(otto_colors)+theme_otto()
# Out:
# <ggplot: (8741112090609)>

# %%
ggplot(df, aes(x='t', y='y'))+geom_line(color=otto_red)+theme_otto()+facet_wrap('function', nrow=2)
# Out:
# <ggplot: (8741111977171)>

# %%
df = pd.DataFrame({'color_name':dynamisch.keys()})
df
# Out:
#        color_name
# 0       deep_navy
# 1           denim
# 2        warm_red
# 3           coral
# 4  positive_green

# %%
ggplot(df, aes(x='color_name', fill='color_name'))+geom_bar()+scale_fill_manual(dynamisch)+theme_otto()+ggtitle("dynamisch")
# Out:
# <ggplot: (8741111918077)>

# %%
df = pd.DataFrame({'color_name':harmonisch.keys()})
ggplot(df, aes(x='color_name', fill='color_name'))+geom_bar()+scale_fill_manual(harmonisch)+theme_otto()+ggtitle("harmonisch")
# Out:
# <ggplot: (8741111912888)>

# %%
df = pd.DataFrame({'color_name':semantic.keys()})
ggplot(df, aes(x='color_name', fill='color_name'))+geom_bar()+scale_fill_manual(semantic)+theme_otto()+ggtitle("semantic")
# Out:
# <ggplot: (8741118473006)>

# %%
df = pd.DataFrame({'color_name':otto_colors})
ggplot(df, aes(x='color_name', fill='color_name'))+geom_bar()+scale_fill_manual(otto_colors)+theme_otto()+ggtitle("otto_colors: custom palet")
# Out:
# <ggplot: (8741111793902)>
